# %% [markdown]
# Another attempt at feature extraction this time using Fast Fourier and Wavelet Transform, as opposed to the fractal decompositions used earlier
#
# Strong Reference:
# Python Emotion using EEG:
#     (https://github.com/shivam-199/Python-Emotion-using-EEG-Signal)

# %%
import os
import sys

import pandas as pd
import numpy as np

import pywt
import scipy.io as spio
from scipy.stats import entropy
from collections import Counter

from sklearn import svm
from sklearn.preprocessing import normalize
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import classification_report

import timeit

# %%
WAVELET = "db6"
MAX_LEVEL = 5

# %%
channel_order = pd.read_csv(r"C:\Users\tanya\OneDrive\Documents\GitHub\LVO-EEG\data\feature_processing\001_EEG_baseline_stroke_study_updated.csv")
channel_order.head()
# Out:
#       TP9     AF7      AF8    TP10
# 0  23.926  11.719  121.094  22.949
# 1  22.461  39.062   -9.277  24.414
# 2  23.926  37.109  -19.531  23.926
# 3  38.574  28.809   47.363  41.992
# 4  52.734  66.895   51.758  57.617

# %%
def calc_wavelet_energy(data_set):
  """
    Input : 1 * N vector
    Output: Float with the wavelet energy of the input vector,
    rounded to 3 decimal places.
  """
  clean = np.square(data_set)
  clean = np.where(clean == 0, 1, clean)
  wavelet_energy = np.nansum(np.log2(clean))
  return round(wavelet_energy, 3)

# %%
def calc_shannon_entropy(data_set):
        """
            Input : 1 * N vector
            Output: Float with the wavelet entropy of the input vector,
                    rounded to 3 decimal places.
        """
        probability = np.square(data_set)
        probability = np.where(probability == 0, 1, probability)
        shannon_entropy = -np.nansum(probability * np.log2(probability))
        return round(shannon_entropy, 3)

# %%
files = os.listdir(r"C:\Users\tanya\OneDrive\Documents\GitHub\LVO-EEG\data\feature_processing")
files
# Out:
# ['001_EEG_baseline_stroke_study_updated.csv',
#  '002_EEG_baseline_stroke_study_updated.csv',
#  '003_EEG_baseline_stroke_study_updated.csv',
#  '004_EEG_baseline_stroke_study_updated.csv',
#  '005_EEG_baseline_stroke_study_updated.csv',
#  '006_EEG_baseline_stroke_study_updated.csv',
#  '007_EEG_baseline_stroke_study_updated.csv',
#  '008_EEG_baseline_stroke_study_updated.csv',
#  '009_EEG_baseline_stroke_study_updated.csv',
#  '010_EEG_baseline_stroke_study_updated.csv',
#  '011_EEG_baseline_stroke_study_updated.csv',
#  '012_EEG_baseline_stroke_study_updated.csv',
#  '013_EEG_baseline_stroke_study_updated.csv',
#  '014_EEG_baseline_stroke_study_updated.csv',
#  '015_EEG_baseline_stroke_study_updated.csv',
#  '016_EEG_baseline_stroke_study_updated.csv',
#  '017_EEG_baseline_stroke_study_updated.csv',
#  '018_EEG_baseline_stroke_study_updated.csv',
#  '019_EEG_baseline_stroke_study_updated.csv',
#  '020_EEG_baseline_stroke_study_updated.csv',
#  '021_EEG_baseline_stroke_study_updated.csv',
#  '022_EEG_baseline_stroke_study_updated.csv',
#  '023_EEG_baseline_stroke_study_updated.csv',
#  '024_EEG_baseline_stroke_study_updated.csv',
#  '025_EEG_baseline_stroke_study_updated.csv',
#  '026_EEG_baseline_stroke_study_updated.csv',
#  '027_EEG_baseline_stroke_study_updated.csv',
#  '028_EEG_baseline_stroke_study_updated.csv',
#  '029_EEG_baseline_stroke_study_updated.csv',
#  '030_EEG_baseline_stroke_study_updated.csv',
#  '031_EEG_baseline_stroke_study_updated.csv',
#  '032_EEG_baseline_stroke_study_updated.csv',
#  '033_EEG_baseline_stroke_study_updated.csv',
#  '034_EEG_baseline_stroke_study_updated.csv',
#  '035_EEG_baseline_stroke_study_updated.csv',
#  '036_EEG_baseline_stroke_study_updated.csv',
#  '037_EEG_baseline_stroke_study_updated.csv',
#  '038_EEG_baseline_stroke_study_updated.csv',
#  '039_EEG_baseline_stroke_study_updated.csv',
#  '040_EEG_baseline_stroke_study_updated.csv',
#  '041_EEG_baseline_stroke_study_updated.csv',
#  '042_EEG_baseline_stroke_study_updated.csv',
#  '043_EEG_baseline_stroke_study_updated.csv',
#  '044_EEG_baseline_stroke_study_updated.csv',
#  '045_EEG_baseline_stroke_study_updated.csv',
#  '046_EEG_baseline_stroke_study_updated.csv',
#  '047_EEG_baseline_stroke_study_updated.csv',
#  '048_EEG_baseline_stroke_study_updated.csv',
#  '049_EEG_baseline_stroke_study_updated.csv',
#  '050_EEG_baseline_stroke_study_updated.csv',
#  '051_EEG_baseline_stroke_study_updated.csv',
#  '052_EEG_baseline_stroke_study_updated.csv',
#  '053_EEG_baseline_stroke_study_updated.csv',
#  '054_EEG_baseline_stroke_study_updated.csv',
#  '055_EEG_baseline_stroke_study_updated.csv',
#  '056_EEG_baseline_stroke_study_updated.csv',
#  '057_EEG_baseline_stroke_study_updated.csv',
#  '058_EEG_baseline_stroke_study_updated.csv',
#  '059_EEG_baseline_stroke_study_updated.csv',
#  '060_EEG_baseline_stroke_study_updated.csv',
#  '061_EEG_baseline_stroke_study_updated.csv',
#  '062_EEG_baseline_stroke_study_updated.csv',
#  '063_EEG_baseline_stroke_study_updated.csv',
#  '064_EEG_baseline_stroke_study_updated.csv',
#  '065_EEG_baseline_stroke_study_updated.csv',
#  '066_EEG_baseline_stroke_study_updated.csv',
#  '067_EEG_baseline_stroke_study_updated.csv',
#  '068_EEG_baseline_stroke_study_updated.csv',
#  '069_EEG_baseline_stroke_study_updated.csv',
#  '070_EEG_baseline_stroke_study_updated.csv',
#  '071_EEG_baseline_stroke_study_updated.csv',
#  '072_EEG_baseline_stroke_study_updated.csv',
#  '073_EEG_baseline_stroke_study_updated.csv',
#  '074_EEG_baseline_stroke_study_updated.csv',
#  '075_EEG_baseline_stroke_study_updated.csv',
#  '076_EEG_baseline_stroke_study_updated.csv',
#  '077_EEG_baseline_stroke_study_updated.csv',
#  '078_EEG_baseline_stroke_study_updated.csv',
#  '079_EEG_baseline_stroke_study_updated.csv',
#  '080_EEG_baseline_stroke_study_updated.csv',
#  '081_EEG_baseline_stroke_study_updated.csv',
#  '082_EEG_baseline_stroke_study_updated.csv',
#  '083_EEG_baseline_stroke_study_updated.csv',
#  '084_EEG_baseline_stroke_study_updated.csv',
#  '085_EEG_baseline_stroke_study_updated.csv',
#  '086_EEG_baseline_stroke_study_updated.csv',
#  '087_EEG_baseline_stroke_study_updated.csv',
#  '088_EEG_baseline_stroke_study_updated.csv',
#  '089_EEG_baseline_stroke_study_updated.csv',
#  '090_EEG_baseline_stroke_study_updated.csv',
#  '091_EEG_baseline_stroke_study_updated.csv',
#  '092_EEG_baseline_stroke_study_updated.csv',
#  '093_EEG_baseline_stroke_study_updated.csv',
#  '094_EEG_baseline_stroke_study_updated.csv',
#  '095_EEG_baseline_stroke_study_updated.csv',
#  '096_EEG_baseline_stroke_study_updated.csv',
#  '097_EEG_baseline_stroke_study_updated.csv',
#  '098_EEG_baseline_stroke_study_updated.csv',
#  '099_EEG_baseline_stroke_study_updated.csv',
#  '100_EEG_baseline_stroke_study_updated.csv',
#  '101_EEG_baseline_stroke_study_updated.csv',
#  '102_EEG_baseline_stroke_study_updated.csv',
#  '103_EEG_baseline_stroke_study_updated.csv',
#  '104_EEG_baseline_stroke_study_updated.csv',
#  '105_EEG_baseline_stroke_study_updated.csv',
#  '106_EEG_baseline_stroke_study_updated.csv',
#  '107_EEG_baseline_stroke_study_updated.csv',
#  '108_EEG_baseline_stroke_study_updated.csv',
#  '109_EEG_baseline_stroke_study_updated.csv',
#  '111_EEG_baseline_stroke_study_updated.csv',
#  '112_EEG_baseline_stroke_study_updated.csv',
#  '113_EEG_baseline_stroke_study_updated.csv',
#  '114_EEG_baseline_stroke_study_updated.csv',
#  '115_EEG_baseline_stroke_study_updated.csv']

# %%
WAVELET = "db6"
MAX_LEVEL = 5 # max level of wavelet decomposition 5 bands

# %%
participant_trial = []
features_table = pd.DataFrame(columns=range(40))
for file in files:#for each participant
    df = pd.read_csv(r"C:\Users\tanya\OneDrive\Documents\GitHub\LVO-EEG\data\feature_processing\\"+file)
    wavEnergy, shannonEntropy = [], []
    for column in df: #for each channel
        oneColumn = df[column].to_numpy()
        dwt_bands = []
        int_ent, int_eng = [], []
        for band in range(MAX_LEVEL):
            (cA, cD) = pywt.dwt(oneColumn, WAVELET)
            dwt_bands.append(cD)   # Append the approximations
        for band in range(len(dwt_bands)):
            int_ent.append(calc_shannon_entropy(dwt_bands[len(dwt_bands) - band - 1]))
            int_eng.append(calc_wavelet_energy(dwt_bands[len(dwt_bands) - band - 1]))
        wavEnergy.append(int_eng)
        shannonEntropy.append(int_ent)
    unroll_entropy = []
    unroll_energy = []
    '''
        Transforming 2D array into 1D vector of features and then 
        combining the two 1D arrays.
    '''
    for i in range(len(shannonEntropy)):
      for j in range(len(shannonEntropy[0])):
        unroll_entropy.append(shannonEntropy[i][j])
        unroll_energy.append(wavEnergy[i][j])

    features = unroll_entropy + unroll_energy
    participant_trial.append(features)
    features_table.loc[len(features_table.index)] = features
    # print(data_file)
    # print(features)
    print(file)
# Out:
# 001_EEG_baseline_stroke_study_updated.csv
# 002_EEG_baseline_stroke_study_updated.csv
# 003_EEG_baseline_stroke_study_updated.csv
# 004_EEG_baseline_stroke_study_updated.csv
# 005_EEG_baseline_stroke_study_updated.csv
# 006_EEG_baseline_stroke_study_updated.csv
# 007_EEG_baseline_stroke_study_updated.csv
# 008_EEG_baseline_stroke_study_updated.csv
# 009_EEG_baseline_stroke_study_updated.csv
# 010_EEG_baseline_stroke_study_updated.csv
# 011_EEG_baseline_stroke_study_updated.csv
# 012_EEG_baseline_stroke_study_updated.csv
# 013_EEG_baseline_stroke_study_updated.csv
# 014_EEG_baseline_stroke_study_updated.csv
# 015_EEG_baseline_stroke_study_updated.csv
# 016_EEG_baseline_stroke_study_updated.csv
# 017_EEG_baseline_stroke_study_updated.csv
# 018_EEG_baseline_stroke_study_updated.csv
# 019_EEG_baseline_stroke_study_updated.csv
# 020_EEG_baseline_stroke_study_updated.csv
# 021_EEG_baseline_stroke_study_updated.csv
# 022_EEG_baseline_stroke_study_updated.csv
# 023_EEG_baseline_stroke_study_updated.csv
# 024_EEG_baseline_stroke_study_updated.csv
# 025_EEG_baseline_stroke_study_updated.csv
# 026_EEG_baseline_stroke_study_updated.csv
# 027_EEG_baseline_stroke_study_updated.csv
# 028_EEG_baseline_stroke_study_updated.csv
# 029_EEG_baseline_stroke_study_updated.csv
# 030_EEG_baseline_stroke_study_updated.csv
# 031_EEG_baseline_stroke_study_updated.csv
# 032_EEG_baseline_stroke_study_updated.csv
# 033_EEG_baseline_stroke_study_updated.csv
# 034_EEG_baseline_stroke_study_updated.csv
# 035_EEG_baseline_stroke_study_updated.csv
# 036_EEG_baseline_stroke_study_updated.csv
# 037_EEG_baseline_stroke_study_updated.csv
# 038_EEG_baseline_stroke_study_updated.csv
# 039_EEG_baseline_stroke_study_updated.csv
# 040_EEG_baseline_stroke_study_updated.csv
# 041_EEG_baseline_stroke_study_updated.csv
# 042_EEG_baseline_stroke_study_updated.csv
# 043_EEG_baseline_stroke_study_updated.csv
# 044_EEG_baseline_stroke_study_updated.csv
# 045_EEG_baseline_stroke_study_updated.csv
# 046_EEG_baseline_stroke_study_updated.csv
# 047_EEG_baseline_stroke_study_updated.csv
# 048_EEG_baseline_stroke_study_updated.csv
# 049_EEG_baseline_stroke_study_updated.csv
# 050_EEG_baseline_stroke_study_updated.csv
# 051_EEG_baseline_stroke_study_updated.csv
# 052_EEG_baseline_stroke_study_updated.csv
# 053_EEG_baseline_stroke_study_updated.csv
# 054_EEG_baseline_stroke_study_updated.csv
# 055_EEG_baseline_stroke_study_updated.csv
# 056_EEG_baseline_stroke_study_updated.csv
# 057_EEG_baseline_stroke_study_updated.csv
# 058_EEG_baseline_stroke_study_updated.csv
# 059_EEG_baseline_stroke_study_updated.csv
# 060_EEG_baseline_stroke_study_updated.csv
# 061_EEG_baseline_stroke_study_updated.csv
# 062_EEG_baseline_stroke_study_updated.csv
# 063_EEG_baseline_stroke_study_updated.csv
# 064_EEG_baseline_stroke_study_updated.csv
# 065_EEG_baseline_stroke_study_updated.csv
# 066_EEG_baseline_stroke_study_updated.csv
# 067_EEG_baseline_stroke_study_updated.csv
# 068_EEG_baseline_stroke_study_updated.csv
# 069_EEG_baseline_stroke_study_updated.csv
# 070_EEG_baseline_stroke_study_updated.csv
# 071_EEG_baseline_stroke_study_updated.csv
# 072_EEG_baseline_stroke_study_updated.csv
# 073_EEG_baseline_stroke_study_updated.csv
# 074_EEG_baseline_stroke_study_updated.csv
# 075_EEG_baseline_stroke_study_updated.csv
# 076_EEG_baseline_stroke_study_updated.csv
# 077_EEG_baseline_stroke_study_updated.csv
# 078_EEG_baseline_stroke_study_updated.csv
# 079_EEG_baseline_stroke_study_updated.csv
# 080_EEG_baseline_stroke_study_updated.csv
# 081_EEG_baseline_stroke_study_updated.csv
# 082_EEG_baseline_stroke_study_updated.csv
# 083_EEG_baseline_stroke_study_updated.csv
# 084_EEG_baseline_stroke_study_updated.csv
# 085_EEG_baseline_stroke_study_updated.csv
# 086_EEG_baseline_stroke_study_updated.csv
# 087_EEG_baseline_stroke_study_updated.csv
# 088_EEG_baseline_stroke_study_updated.csv
# 089_EEG_baseline_stroke_study_updated.csv
# 090_EEG_baseline_stroke_study_updated.csv
# 091_EEG_baseline_stroke_study_updated.csv
# 092_EEG_baseline_stroke_study_updated.csv
# 093_EEG_baseline_stroke_study_updated.csv
# 094_EEG_baseline_stroke_study_updated.csv
# 095_EEG_baseline_stroke_study_updated.csv
# 096_EEG_baseline_stroke_study_updated.csv
# 097_EEG_baseline_stroke_study_updated.csv
# 098_EEG_baseline_stroke_study_updated.csv
# 099_EEG_baseline_stroke_study_updated.csv
# 100_EEG_baseline_stroke_study_updated.csv
# 101_EEG_baseline_stroke_study_updated.csv
# 102_EEG_baseline_stroke_study_updated.csv
# 103_EEG_baseline_stroke_study_updated.csv
# 104_EEG_baseline_stroke_study_updated.csv
# 105_EEG_baseline_stroke_study_updated.csv
# 106_EEG_baseline_stroke_study_updated.csv
# 107_EEG_baseline_stroke_study_updated.csv
# 108_EEG_baseline_stroke_study_updated.csv
# 109_EEG_baseline_stroke_study_updated.csv
# 111_EEG_baseline_stroke_study_updated.csv
# 112_EEG_baseline_stroke_study_updated.csv
# 113_EEG_baseline_stroke_study_updated.csv
# 114_EEG_baseline_stroke_study_updated.csv
# 115_EEG_baseline_stroke_study_updated.csv

# %%
file_dir = r"C:\Users\tanya\OneDrive\Documents\GitHub\LVO-EEG\data\feature_processed"

# %%
features_table.to_csv(file_dir + "features" + WAVELET + ".csv", index=False)

# %%
features_table.to_csv(r"C:\Users\tanya\OneDrive\Documents\GitHub\LVO-EEG\data\feature_processed"+r"\features.csv", index=False)

# %%
data = pd.read_csv(r"C:\Users\tanya\OneDrive\Documents\GitHub\LVO-EEG\data\feature_processed"+r"\features.csv")
