# %%
import numpy as np
import pandas as pd
from models.eegnetGyroACC import EEGNet
import torch

# %%
example = np.random.rand(113, 1, 2807, 10)
example = torch.FloatTensor(example)
model = EEGNet(output=1)
model(example)
# Out:
# tensor([[0.7690],
#         [0.5415],
#         [0.4973],
#         [0.6473],
#         [0.7238],
#         [0.6734],
#         [0.5560],
#         [0.5497],
#         [0.5472],
#         [0.7120],
#         [0.5842],
#         [0.6964],
#         [0.6778],
#         [0.5806],
#         [0.5514],
#         [0.6254],
#         [0.6317],
#         [0.5011],
#         [0.5823],
#         [0.6779],
#         [0.7675],
#         [0.5476],
#         [0.7414],
#         [0.5419],
#         [0.6167],
#         [0.6452],
#         [0.6433],
#         [0.6858],
#         [0.6150],
#         [0.4585],
#         [0.7274],
#         [0.5226],
#         [0.7056],
#         [0.5965],
#         [0.6228],
#         [0.8081],
#         [0.6555],
#         [0.7630],
#         [0.6966],
#         [0.5403],
#         [0.6119],
#         [0.6251],
#         [0.5362],
#         [0.6471],
#         [0.5660],
#         [0.5093],
#         [0.6476],
#         [0.4826],
#         [0.5696],
#         [0.5645],
# ...
